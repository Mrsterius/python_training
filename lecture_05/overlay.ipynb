# %%
import numpy as np
import matplotlib.pyplot as plt
import PIL
import cv2

# %%
cb_pil = PIL.Image.open("cb.png")

# %%
cb_np = np.array(cb_pil)

# %%
cb_np.shape
# Out:
# (189, 454, 4)

# %%
panda_pil = PIL.Image.open("../lecture_01/panda_image.jpg")

# %%
panda_np = np.array(panda_pil)

# %%
panda_np.shape
# Out:
# (433, 600, 3)

# %%
cut = panda_np[0:cb_np.shape[0], -cb_np.shape[1]:]

# %%
plt.imshow(cut)

# %%
plt.imshow(panda_np)

# %%
for row in range(cb_np.shape[0]):
    for col in range(cb_np.shape[1]):
        if cb_np[row, col, 3] > 100:
            cut[row, col] = cb_np[row, col, :3]

# %%
plt.imshow(panda_np)
