# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
img = np.zeros((100,100,3), dtype = np.uint8)

# %%
plt.imshow(img)

# %%
img[:30, :, 0] = 255

# %%
plt.imshow(img)

# %%
img[30:60, :, 1] = 255

# %%
img[60:, :, 2] = 255

# %%
plt.imshow(img)

# %%
import PIL

# %%
pan = PIL.Image.open("../lecture_01/panda_image.jpg")

# %%
type(pan)
# Out:
# PIL.JpegImagePlugin.JpegImageFile

# %%
pan
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=600x433 at 0x112E2DD10>

# %%
np_img = np.array(pan)

# %%
type(np_img)
# Out:
# numpy.ndarray

# %%
np_img.shape
# Out:
# (433, 600, 3)

# %%
np_img.dtype
# Out:
# dtype('uint8')

# %%
plt.imshow(np_img)

# %%
np_img[:,:,0] = 0

# %%
plt.imshow(np_img)

# %%
short = np_img[::2, ::2]

# %%
plt.imshow(short)

# %%
img = PIL.Image.fromarray(np_img)

# %%
img
# Out:
# <PIL.Image.Image image mode=RGB size=600x433 at 0x112354FD0>

# %%
f = open("myedit.jpg", "wb")
img.save(f)
