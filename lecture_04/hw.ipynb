# %%
import numpy as np
import PIL
import matplotlib.pyplot as plt

# %%
t_img = PIL.Image.open("clouds.png")
img = PIL.Image.open("panda_image.jpg")

# %%
t_img
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=100x100 at 0x11FCFA750>

# %%
t_arr = np.array(t_img)
img_arr = np.array(img)

# %%
img_arr
# Out:
# array([[[ 11,  20,  17],
#         [ 11,  20,  17],
#         [ 11,  20,  17],
#         ...,
#         [ 10,  11,   5],
#         [  8,   9,   4],
#         [  5,   6,   1]],
#
#        [[ 11,  20,  17],
#         [ 11,  20,  17],
#         [ 12,  21,  18],
#         ...,
#         [  9,  10,   4],
#         [  8,   9,   3],
#         [  7,   8,   2]],
#
#        [[ 11,  20,  17],
#         [ 12,  21,  18],
#         [ 12,  21,  18],
#         ...,
#         [  2,   3,   0],
#         [  4,   5,   0],
#         [  5,   6,   0]],
#
#        ...,
#
#        [[197, 190, 182],
#         [198, 191, 183],
#         [198, 191, 183],
#         ...,
#         [122, 113, 116],
#         [127, 118, 121],
#         [132, 123, 126]],
#
#        [[202, 195, 187],
#         [201, 194, 186],
#         [200, 193, 185],
#         ...,
#         [ 97,  88,  91],
#         [104,  95,  98],
#         [111, 102, 105]],
#
#        [[206, 197, 188],
#         [205, 196, 187],
#         [204, 195, 186],
# ...

# %%
t_arr[:,:,3] = 100

# %%
t_img = PIL.Image.fromarray(t_arr)

# %%
t_img
# Out:
# <PIL.Image.Image image mode=RGBA size=100x100 at 0x11FFDEED0>

# %%
img.size
# Out:
# (600, 433)

# %%
img.paste(t_img, (500,0),t_img)

# %%
img
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=600x433 at 0x11F977610>

# %%
img.save("img_overlay.jpg")
