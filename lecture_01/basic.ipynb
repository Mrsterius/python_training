# %%
a = 9

# %%
print(a)
# Out:
# 9

# %%
type (1000*10000)
# Out:
# int

# %%
1000**10000
# Out:
# ...

# %%
11 / 3
# Out:
# 3.6666666666666665

# %%
11 // 3
# Out:
# 3

# %%
-1 % 3
# Out:
# 2

# %%
-1 % -3
# Out:
# -1

# %%
# float discussion

# %%
b = 7777777777777777777777777777777.77777777777777777777

# %%
b
# Out:
# 7.777777777777777e+30

# %%
c = 1 + 5j

# %%
c.real
# Out:
# 1.0

# %%
c.imag
# Out:
# 5.0

# %%
c
# Out:
# (1+5j)

# %%
a.bit_length
# Out:
# <function int.bit_length()>

# %%
a.bit_length()
# Out:
# 4

# %%
a.real
# Out:
# 9

# %%
a.imag
# Out:
# 0

# %%
True and True
# Out:
# True

# %%
False or True
# Out:
# True

# %%
not True
# Out:
# False

# %%
_4 = 6

# %%
_4
# Out:
# 6

# %%
d = 0b10

# %%
d
# Out:
# 2

# %%
d = 0x10

# %%
d
# Out:
# 16

# %%
d = 0o10

# %%
d
# Out:
# 8

# %%
d = 010
# Out:
#   File "<ipython-input-42-be0d5f9b699c>", line 1
#     d = 010
#           ^
# SyntaxError: invalid token
