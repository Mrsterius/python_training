# %%
f = open("hello.txt", "wt")

# %%
f.write("hello world")
# Out:
# 11

# %%
f.flush() # saves to disk

# %%
f.close()

# %%
import requests

# %%
url = r"https://www.google.com/"

# %%
result = requests.get(url)

# %%
result.status_code
# Out:
# 200

# %%
result.text
# Out:
# '<!doctype html><html itemscope="" itemtype="http://schema.org/WebPage" lang="en-IN"><head><meta content="text/html; charset=UTF-8" http-equiv="Content-Type"><meta content="/images/branding/googleg/1x/googleg_standard_color_128dp.png" itemprop="image"><title>Google</title><script nonce="vwqTjaEAKDSJpZ1e8jPOng==">(function(){window.google={kEI:\'z6ImXqalBLvG4-EP3tuw2AI\',kEXPI:\'0,1353747,5662,730,224,4727,377,207,2955,249,10,1051,175,173,179,12,214,940,3,205,73,4,60,692,50,208,10,754,490,1128224,143,1197757,392,28,329090,1294,12383,4855,32692,15247,867,19398,9286,364,3319,5505,8384,4859,1361,283,4040,4968,3022,3895,3968,7915,1808,1976,2044,5762,1,3146,5297,2054,920,873,1217,1336,1047,592,4294,1720,1,415,1141,7512,1781,252,620,2883,21,318,689,1291,1192,1344,2778,520,399,2279,6,2796,1593,1279,2212,202,328,149,1103,327,515,515,318,1156,48,820,3438,260,52,1132,4,3,2063,606,1839,184,545,50,366,816,143,377,259,293,134,1261,692,56,428,44,1009,93,330,1282,16,84,362,55,2426,2246,474,1339,29,1
# ...

# %%
f = open("google.html", "wt")
f.write(result.text)
f.close()

# %%
import requests
url = r"https://api.time.com/wp-content/uploads/2015/02/panda-cub.jpg?w=600&quality=85"
result = requests.get(url)
f = open("panda_image.jpg", "wb")
f.write(result.content)
f.close()
# Out:
# ---------------------------------------------------------------------------
# gaierror                                  Traceback (most recent call last)
# /opt/anaconda3/lib/python3.7/site-packages/urllib3/connection.py in _new_conn(self)
#     158             conn = connection.create_connection(
# --> 159                 (self._dns_host, self.port), self.timeout, **extra_kw)
#     160
#
# /opt/anaconda3/lib/python3.7/site-packages/urllib3/util/connection.py in create_connection(address, timeout, source_address, socket_options)
#      56
# ---> 57     for res in socket.getaddrinfo(host, port, family, socket.SOCK_STREAM):
#      58         af, socktype, proto, canonname, sa = res
#
# /opt/anaconda3/lib/python3.7/socket.py in getaddrinfo(host, port, family, type, proto, flags)
#     747     addrlist = []
# --> 748     for res in _socket.getaddrinfo(host, port, family, type, proto, flags):
#     749         af, socktype, proto, canonname, sa = res
#
# ...

# %%
result.text
# Out:
# '����\x00\x10JFIF\x00\x01\x01\x01\x00H\x00H\x00\x00��\x00�Exif\x00\x00II*\x00\x08\x00\x00\x00\x06\x00\x1a\x01\x05\x00\x01\x00\x00\x00V\x00\x00\x00\x1b\x01\x05\x00\x01\x00\x00\x00^\x00\x00\x00(\x01\x03\x00\x01\x00\x00\x00\x02\x00\x00\x001\x01\x02\x00\x1e\x00\x00\x00f\x00\x00\x002\x01\x02\x00\x1a\x00\x00\x00�\x00\x00\x00i�\x04\x00\x01\x00\x00\x00�\x00\x00\x00\x00\x00\x00\x00,\x01\x00\x00\x01\x00\x00\x00,\x01\x00\x00\x01\x00\x00\x00Adobe Photoshop CS5 Macintosh\x002015-02-28T14:21:29-05:00\x00\x03\x00\x00�\x07\x00\x04\x00\x00\x000220\x02�\x04\x00\x01\x00\x00\x00\x00\n\x00\x00\x03�\x04\x00\x01\x00\x00\x00;\x07\x00\x00\x00\x00\x00\x00;\x07\x00\x00\x00\x00��\x03�Photoshop 3.0\x008BIM\x04\x04\x00\x00\x00\x00\x03�\x1c\x01Z\x00\x03\x1b%G\x1c\x02\x00\x00\x02\x00\x02\x1c\x02x\x01�Mother giant panda Juxiao is seen with one of her triplets at Chimelong Safari Park in Guangzhou, Guangdong province, December 9, 2014. According to local media, this is the fourth set of giant panda triplets born with
# ...

# %%
result.content
# Out:
# b'\xff\xd8\xff\xe0\x00\x10JFIF\x00\x01\x01\x01\x00H\x00H\x00\x00\xff\xe1\x00\xd6Exif\x00\x00II*\x00\x08\x00\x00\x00\x06\x00\x1a\x01\x05\x00\x01\x00\x00\x00V\x00\x00\x00\x1b\x01\x05\x00\x01\x00\x00\x00^\x00\x00\x00(\x01\x03\x00\x01\x00\x00\x00\x02\x00\x00\x001\x01\x02\x00\x1e\x00\x00\x00f\x00\x00\x002\x01\x02\x00\x1a\x00\x00\x00\x84\x00\x00\x00i\x87\x04\x00\x01\x00\x00\x00\x9e\x00\x00\x00\x00\x00\x00\x00,\x01\x00\x00\x01\x00\x00\x00,\x01\x00\x00\x01\x00\x00\x00Adobe Photoshop CS5 Macintosh\x002015-02-28T14:21:29-05:00\x00\x03\x00\x00\x90\x07\x00\x04\x00\x00\x000220\x02\xa0\x04\x00\x01\x00\x00\x00\x00\n\x00\x00\x03\xa0\x04\x00\x01\x00\x00\x00;\x07\x00\x00\x00\x00\x00\x00;\x07\x00\x00\x00\x00\xff\xed\x03\xbePhotoshop 3.0\x008BIM\x04\x04\x00\x00\x00\x00\x03\x85\x1c\x01Z\x00\x03\x1b%G\x1c\x02\x00\x00\x02\x00\x02\x1c\x02x\x01\xd9Mother giant panda Juxiao is seen with one of her triplets at Chimelong Safari Park in Guangzhou, Guangdong province, December 9, 2014. According to local media, t
# ...
